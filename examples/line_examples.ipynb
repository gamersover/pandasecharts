# %%
# import sys
# sys.path.append("../")
import pandas as pd
from pyecharts.faker import Faker
from pandasecharts import echart
from pandasecharts.echart import DataFrameEcharts as DFE

# %%
products = Faker.choose()
dfs = []
for year in (2012, 2013, 2014, 2015):
    dfs.append(
        pd.DataFrame(
            zip(products, Faker.values(), Faker.values(), [year]*len(products)),
            columns=["商品", "商家A", "商家B", "年份"]
        )
    )
df = pd.concat(dfs, axis=0)

# %%
df.head()
# Out:
#    商品  商家A  商家B    年份
# 0  可乐  128   40  2012
# 1  雪碧  125   84  2012
# 2  橙汁   95  137  2012
# 3  绿茶   97  117  2012
# 4  奶茶   96   36  2012

# %%
t_all: "DFE" = df.echart

# %% [markdown]
# 商家A总销量与年份的关系

# %%
t_all.line("年份", "商家A", agg_func="sum", xtype="category", smooth=True).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="20ac24ccea6a4a0296f810eccd9ed100" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_20ac24ccea6a4a0296f810eccd9ed100 = echarts.init(
#                     document.getElementById('20ac24ccea6a4a0296f810eccd9ed100'), 'white', {renderer: 'canvas'});
#                 var option_20ac24ccea6a4a0296f810eccd9ed100 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# 所有商家总销量与年份的关系

# %%
t_all.line("年份", ["商家A", "商家B"], agg_func="sum", xtype="category").render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3dede60dd93e45208897bcfdb642aa00" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3dede60dd93e45208897bcfdb642aa00 = echarts.init(
#                     document.getElementById('3dede60dd93e45208897bcfdb642aa00'), 'white', {renderer: 'canvas'});
#                 var option_3dede60dd93e45208897bcfdb642aa00 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# 主题设置

# %%
t_all.line("年份", ["商家A", "商家B"], agg_func="sum", xtype="category", theme="light").render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e3758bc725644f5d9df4eb408786adde" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e3758bc725644f5d9df4eb408786adde = echarts.init(
#                     document.getElementById('e3758bc725644f5d9df4eb408786adde'), 'light', {renderer: 'canvas'});
#                 var option_e3758bc725644f5d9df4eb408786adde = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6A",
#             "connectNulls": false,
# ...

# %% [markdown]
# 多个Y轴显示

# %%
t_all.line("年份", ["商家A", "商家B"], agg_func="sum", xtype="category", multiple_yaxis=True).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="77c95e055af34391b06cbacb08626b24" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_77c95e055af34391b06cbacb08626b24 = echarts.init(
#                     document.getElementById('77c95e055af34391b06cbacb08626b24'), 'white', {renderer: 'canvas'});
#                 var option_77c95e055af34391b06cbacb08626b24 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# 不同商品在所有商家的年销量

# %%
t_all.line("年份", ["商家A", "商家B"], xtype="category", by="商品", multiple_yaxis=True).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a00ab281490d4845b2d963f5f8a8a568" style="width:900px; height:500px;"></div>
#         <div id="e1ecba00b7f3473b809a0ce872332515" style="width:900px; height:500px;"></div>
#         <div id="49fe478f257542dead58a92c1f72383d" style="width:900px; height:500px;"></div>
#         <div id="170482b3810e4924bf7df614930801d1" style="width:900px; height:500px;"></div>
#         <div id="35b968e24a734c40a43354932553070f" style="width:900px; height:500px;"></div>
#         <div id="9e031028d2d743bb8c15bd1a00852957" style="width:900px; height:500px;"></div>
#         <div id="fc35cd6900ca44baa7cee1d62d3963cd" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a00ab281490d4845b2d963f5f8a8a568 = echarts.init(
# ...

# %% [markdown]
# 将不同商品作为时间轴来显示

# %%
t_all.line("年份", ["商家A", "商家B"], xtype="category", timeline="商品").render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d5591239bc20454a979120072a0795c0" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d5591239bc20454a979120072a0795c0 = echarts.init(
#                     document.getElementById('d5591239bc20454a979120072a0795c0'), 'white', {renderer: 'canvas'});
#                 var option_d5591239bc20454a979120072a0795c0 = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "line",
#                 "name": "\u5546\u5bb6A",
#                 "connectNulls": false,
#                 "symbolSize": 4,
#                 "showSymbol": true,
#                 "smooth": false,
#                 "clip": true,
#                 "step": false,
#                 "data": [
#                     [
# ...
