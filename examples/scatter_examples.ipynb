# %%
# import sys
# sys.path.append("../")
import pandas as pd
from pyecharts.faker import Faker
from pandasecharts import echart
from pandasecharts.echart import DataFrameEcharts as DFE

# %%
products = Faker.choose()
dfs = []
for year in (2012, 2013, 2014, 2015):
    dfs.append(
        pd.DataFrame(
            zip(products, Faker.values(), Faker.values(), [year]*len(products)),
            columns=["商品", "商家A", "商家B", "年份"]
        )
    )
df = pd.concat(dfs, axis=0)

# %%
df.head()
# Out:
#    商品  商家A  商家B    年份
# 0  周一   59   28  2012
# 1  周二  146  110  2012
# 2  周三  125  146  2012
# 3  周四   38  140  2012
# 4  周五  111   89  2012

# %%
t_2012: "DFE" = df.query("年份 == 2012").echart
t_all: "DFE" = df.echart

# %% [markdown]
# 2012年所有商品在商家A的销量

# %%
t_2012.scatter("商品" , "商家A", xtype="category").render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="610835327b444a92b790b13208b4cee4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_610835327b444a92b790b13208b4cee4 = echarts.init(
#                     document.getElementById('610835327b444a92b790b13208b4cee4'), 'white', {renderer: 'canvas'});
#                 var option_610835327b444a92b790b13208b4cee4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# 2012年商品在不同商家的销量

# %%
t_2012.scatter("商品" , ["商家A", "商家B"], xtype="category").render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3d954cc7d6ca4b8d9cb73c986f65f583" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3d954cc7d6ca4b8d9cb73c986f65f583 = echarts.init(
#                     document.getElementById('3d954cc7d6ca4b8d9cb73c986f65f583'), 'white', {renderer: 'canvas'});
#                 var option_3d954cc7d6ca4b8d9cb73c986f65f583 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# 多Y轴显示

# %%
t_2012.scatter("商品" , ["商家A", "商家B"], 
                                     xtype="category", 
                                     multiple_yaxis=True).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="13c54de85e7745a69b8ea3d9313498b2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_13c54de85e7745a69b8ea3d9313498b2 = echarts.init(
#                     document.getElementById('13c54de85e7745a69b8ea3d9313498b2'), 'white', {renderer: 'canvas'});
#                 var option_13c54de85e7745a69b8ea3d9313498b2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# 主题设置

# %%
t_2012.scatter("商品" , ["商家A", "商家B"], 
                                     xtype="category", 
                                     theme="light").render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="8c68373e88584c83a825563d8ef6b8a3" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_8c68373e88584c83a825563d8ef6b8a3 = echarts.init(
#                     document.getElementById('8c68373e88584c83a825563d8ef6b8a3'), 'light', {renderer: 'canvas'});
#                 var option_8c68373e88584c83a825563d8ef6b8a3 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u5546\u5bb6A",
#             "symbolSize": 10,
# ...

# %% [markdown]
# 按照年份显示多张图表

# %%
t_all.scatter("商品" , ["商家A", "商家B"], 
                  xtype="category", 
                  by="年份").render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="8611022ad6fb438b88893a9640a784af" style="width:900px; height:500px;"></div>
#         <div id="6ec3ad1dfde64e0b8e443fb020cd83e0" style="width:900px; height:500px;"></div>
#         <div id="401fe2e9dc3045118cd92f26f6cffcda" style="width:900px; height:500px;"></div>
#         <div id="840d7e41318d46d8a30b1ec4d289c068" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_8611022ad6fb438b88893a9640a784af = echarts.init(
#                     document.getElementById('8611022ad6fb438b88893a9640a784af'), 'white', {renderer: 'canvas'});
#                 var option_8611022ad6fb438b88893a9640a784af = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
# ...

# %% [markdown]
# 将时间改为时间轴

# %%
t_all.scatter("商品" , ["商家A", "商家B"], 
                  xtype="category", 
                  timeline="年份").render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="6df30fbf38f34dac968161c19120427a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_6df30fbf38f34dac968161c19120427a = echarts.init(
#                     document.getElementById('6df30fbf38f34dac968161c19120427a'), 'white', {renderer: 'canvas'});
#                 var option_6df30fbf38f34dac968161c19120427a = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "scatter",
#                 "name": "\u5546\u5bb6A",
#                 "symbolSize": 10,
#                 "data": [
#                     [
#                         "\u5468\u4e00",
#                         142
#                     ],
#                     [
#                         "\u5468\u4e8c",
#                         37
# ...
