# %%
# import sys
# sys.path.append("../")
import pandas as pd
from pyecharts.faker import Faker
from pandasecharts import echart
from pandasecharts.echart import DataFrameEcharts as DFE

# %%
products = Faker.choose()
dfs = []
for year in (2012, 2013, 2014, 2015):
    dfs.append(
        pd.DataFrame(
            zip(products, Faker.values(), Faker.values(), [year]*len(products)),
            columns=["商品", "商家A", "商家B", "年份"]
        )
    )
df = pd.concat(dfs, axis=0)

# %%
t_2012: "DFE" = df.query("年份==2012").echart
t_all: "DFE" = df.echart

# %% [markdown]
# 2012年商家A的漏斗图

# %%
t_2012.funnel("商品", "商家A").render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5beb46efff40472da7bc5524519ec343" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5beb46efff40472da7bc5524519ec343 = echarts.init(
#                     document.getElementById('5beb46efff40472da7bc5524519ec343'), 'white', {renderer: 'canvas'});
#                 var option_5beb46efff40472da7bc5524519ec343 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 {
#                     "name": "\u53ef\u4e50",
#                     "value": 41
#                 },
#                 {
#                     "name": "\u96ea\u78a7",
#                     "value": 114
#                 },
#                 {
#                     "name": "\u6a59\u6c41",
#                     "value": 93
#                 },
#                 {
#                     "name": "\u7eff\u8336",
#                     "value": 74
#                 },
#                 {
#                     "name": "\u5976\u8336",
#                     "value": 73
#                 },
#                 {
#                     "name": "\u767e\u5a01",
#                     "value": 125
#                 },
#                 {
#                     "name": "\u9752\u5c9b",
#                     "value": 43
#                 }
#             ],
#             "sort": "desending",
#             "gap": 0,
#             "label": {
#                 "show": true,
#                 "position": "inner",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7eff\u8336",
#                 "\u767e\u5a01",
#                 "\u96ea\u78a7",
#                 "\u9752\u5c9b",
#                 "\u53ef\u4e50",
#                 "\u5976\u8336",
#                 "\u6a59\u6c41"
#             ],
#             "selected": {
#                 "\u53ef\u4e50": true,
#                 "\u96ea\u78a7": true,
#                 "\u6a59\u6c41": true,
#                 "\u7eff\u8336": true,
#                 "\u5976\u8336": true,
#                 "\u767e\u5a01": true,
#                 "\u9752\u5c9b": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_5beb46efff40472da7bc5524519ec343.setOption(option_5beb46efff40472da7bc5524519ec343);
#         });
#     </script>

# %% [markdown]
# 商家A不同年份漏斗图

# %%
t_all.funnel("商品", "商家A", by="年份").render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="864323f5dca047e9ad7fe7c267297760" style="width:900px; height:500px;"></div>
#         <div id="4be4f57bf1c04c13ba21c23514a61d9f" style="width:900px; height:500px;"></div>
#         <div id="6bcc95b08b8a4fa8b6fec4aec478a940" style="width:900px; height:500px;"></div>
#         <div id="4757756d0c474110b02dd4d83adb85c2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_864323f5dca047e9ad7fe7c267297760 = echarts.init(
#                     document.getElementById('864323f5dca047e9ad7fe7c267297760'), 'white', {renderer: 'canvas'});
#                 var option_864323f5dca047e9ad7fe7c267297760 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 {
#                     "name": "\u53ef\u4e50",
#                     "value": 41
#                 },
#                 {
#                     "name": "\u96ea\u78a7",
#                     "value": 114
#                 },
#                 {
#                     "name": "\u6a59\u6c41",
#                     "value": 93
#                 },
#                 {
#                     "name": "\u7eff\u8336",
#                     "value": 74
#                 },
#                 {
#                     "name": "\u5976\u8336",
#                     "value": 73
#                 },
#                 {
#                     "name": "\u767e\u5a01",
#                     "value": 125
#                 },
#                 {
#                     "name": "\u9752\u5c9b",
#                     "value": 43
#                 }
#             ],
#             "sort": "desending",
#             "gap": 0,
#             "label": {
#                 "show": true,
#                 "position": "inner",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7eff\u8336",
#                 "\u767e\u5a01",
#                 "\u96ea\u78a7",
#                 "\u9752\u5c9b",
#                 "\u53ef\u4e50",
#                 "\u5976\u8336",
#                 "\u6a59\u6c41"
#             ],
#             "selected": {
#                 "\u53ef\u4e50": true,
#                 "\u96ea\u78a7": true,
#                 "\u6a59\u6c41": true,
#                 "\u7eff\u8336": true,
#                 "\u5976\u8336": true,
#                 "\u767e\u5a01": true,
#                 "\u9752\u5c9b": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "subtext": "\u5e74\u4efd=2012",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_864323f5dca047e9ad7fe7c267297760.setOption(option_864323f5dca047e9ad7fe7c267297760);
#                 var chart_4be4f57bf1c04c13ba21c23514a61d9f = echarts.init(
#                     document.getElementById('4be4f57bf1c04c13ba21c23514a61d9f'), 'white', {renderer: 'canvas'});
#                 var option_4be4f57bf1c04c13ba21c23514a61d9f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 {
#                     "name": "\u53ef\u4e50",
#                     "value": 57
#                 },
#                 {
#                     "name": "\u96ea\u78a7",
#                     "value": 127
#                 },
#                 {
#                     "name": "\u6a59\u6c41",
#                     "value": 35
#                 },
#                 {
#                     "name": "\u7eff\u8336",
#                     "value": 130
#                 },
#                 {
#                     "name": "\u5976\u8336",
#                     "value": 57
#                 },
#                 {
#                     "name": "\u767e\u5a01",
#                     "value": 113
#                 },
#                 {
#                     "name": "\u9752\u5c9b",
#                     "value": 87
#                 }
#             ],
#             "sort": "desending",
#             "gap": 0,
#             "label": {
#                 "show": true,
#                 "position": "inner",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7eff\u8336",
#                 "\u767e\u5a01",
#                 "\u96ea\u78a7",
#                 "\u9752\u5c9b",
#                 "\u53ef\u4e50",
#                 "\u5976\u8336",
#                 "\u6a59\u6c41"
#             ],
#             "selected": {
#                 "\u53ef\u4e50": true,
#                 "\u96ea\u78a7": true,
#                 "\u6a59\u6c41": true,
#                 "\u7eff\u8336": true,
#                 "\u5976\u8336": true,
#                 "\u767e\u5a01": true,
#                 "\u9752\u5c9b": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "subtext": "\u5e74\u4efd=2013",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_4be4f57bf1c04c13ba21c23514a61d9f.setOption(option_4be4f57bf1c04c13ba21c23514a61d9f);
#                 var chart_6bcc95b08b8a4fa8b6fec4aec478a940 = echarts.init(
#                     document.getElementById('6bcc95b08b8a4fa8b6fec4aec478a940'), 'white', {renderer: 'canvas'});
#                 var option_6bcc95b08b8a4fa8b6fec4aec478a940 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurat

# %% [markdown]
# 将年份按照时间轴显示

# %%
t_all.funnel("商品", "商家A", timeline="年份").render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3ada8405e7e947968a537358e55d628d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3ada8405e7e947968a537358e55d628d = echarts.init(
#                     document.getElementById('3ada8405e7e947968a537358e55d628d'), 'white', {renderer: 'canvas'});
#                 var option_3ada8405e7e947968a537358e55d628d = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "funnel",
#                 "name": "\u5546\u5bb6A",
#                 "data": [
#                     {
#                         "name": "\u53ef\u4e50",
#                         "value": 63
#                     },
#                     {
#                         "name": "\u96ea\u78a7",
#                         "value": 76
#                     },
#                     {
#                         "name": "\u6a59\u6c41",
#                         "value": 113
#                     },
#                     {
#                         "name": "\u7eff\u8336",
#                         "value": 68
#                     },
#                     {
#                         "name": "\u5976\u8336",
#                         "value": 48
#                     },
#                     {
#                         "name": "\u767e\u5a01",
#                         "value": 41
#                     },
#                     {
#                         "name": "\u9752\u5c9b",
#                         "value": 116
#                     }
#                 ],
#                 "sort": "desending",
#                 "gap": 0,
#                 "label": {
#                     "show": true,
#                     "position": "inner",
#                     "margin": 8
#                 }
#             }
#         ],
#         "timeline": {
#             "axisType": "category",
#             "orient": "horizontal",
#             "autoPlay": false,
#             "controlPosition": "left",
#             "loop": true,
#             "rewind": false,
#             "show": true,
#             "inverse": false,
#             "bottom": "-5px",
#             "data": [
#                 "2012",
#                 "2013",
#                 "2014",
#                 "2015"
#             ]
#         }
#     },
#     "options": [
#         {
#             "legend": [
#                 {
#                     "data": [
#                         "\u7eff\u8336",
#                         "\u767e\u5a01",
#                         "\u96ea\u78a7",
#                         "\u9752\u5c9b",
#                         "\u53ef\u4e50",
#                         "\u5976\u8336",
#                         "\u6a59\u6c41"
#                     ],
#                     "selected": {
#                         "\u53ef\u4e50": true,
#                         "\u96ea\u78a7": true,
#                         "\u6a59\u6c41": true,
#                         "\u7eff\u8336": true,
#                         "\u5976\u8336": true,
#                         "\u767e\u5a01": true,
#                         "\u9752\u5c9b": true
#                     },
#                     "show": true,
#                     "padding": 5,
#                     "itemGap": 10,
#                     "itemWidth": 25,
#                     "itemHeight": 14
#                 }
#             ],
#             "series": [
#                 {
#                     "type": "funnel",
#                     "name": "\u5546\u5bb6A",
#                     "data": [
#                         {
#                             "name": "\u53ef\u4e50",
#                             "value": 41
#                         },
#                         {
#                             "name": "\u96ea\u78a7",
#                             "value": 114
#                         },
#                         {
#                             "name": "\u6a59\u6c41",
#                             "value": 93
#                         },
#                         {
#                             "name": "\u7eff\u8336",
#                             "value": 74
#                         },
#                         {
#                             "name": "\u5976\u8336",
#                             "value": 73
#                         },
#                         {
#                             "name": "\u767e\u5a01",
#                             "value": 125
#                         },
#                         {
#                             "name": "\u9752\u5c9b",
#                             "value": 43
#                         }
#                     ],
#                     "sort": "desending",
#                     "gap": 0,
#                     "label": {
#                         "show": true,
#                         "position": "inner",
#                         "margin": 8
#                     }
#                 }
#             ],
#             "title": [
#                 {
#                     "text": "\u5e74\u4efd=2012",
#                     "padding": 5,
#                     "itemGap": 10
#                 }
#             ],
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "showContent": true,
#                 "alwaysShowContent": false,
#                 "showDelay": 0,
#                 "hideDelay": 100,
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0,
#                 "padding": 5
#             },
#             "color": [
#                 "#c23531",
#                 "#2f4554",
#                 "#61a0a8",
#                 "#d48265",
#                 "#749f83",
#                 "#ca8622",
#                 "#bda29a",
#                 "#6e7074",
#                 "#546570",
#                 "#c4ccd3",
#                 "#f05b72",
#                 "#ef5b9c",
#                 "#f47920",
#                 "#905a3d",
#                 "#fab27b",
#                 "#2a5caa",
#                 "#444693",
#                 "#726930",
#                 "#b2d235",
#                 "#6d8346",
#                 "#ac6767",
#                 "#1d953f",
#                 "#6950a1",
#                 "#918597"
#             ]
#         },
#         {
#             "legend": [
#                 {
#                     "data": [
#                         "\u7eff\u8336",
#                         "\u767e\u5a01",
#                         "\u96ea\u78a7",
#                         "\u9752\u5c9b",
#                         "\u53ef\u4e50",
#                         "\u5976\u8336",
#                         "\u6a59\u6c41"
#                     ],
#                     "selected": {
#                         "\u53ef\u4e50": true,
#                         "\u96ea\u78a7": true,
#                         "\u6a59\u6c41": true,
#                         "\u7eff\u8336": true,
#                         "\u5976\u8336": true,
#                         "\u767e\u5a01": true,
#                         "\u9752\u5c9b": true
#                     },
#                     "show": true,
#                     "padding": 5,
#                     "itemGap": 10,
#                     "itemWidth": 25,
#                     "itemHeight": 14
#                 }
#             ],
#             "series": [
#                 {
#                     "type": "funnel",
#                     "name": "\u5546\u5bb6A",
#                     "data": [
#                         {
#                             "name": "\u53ef\u4e50",
#                             "value": 57
#                         },
#                         {
#                             "name": "\u96ea\u78a7",
#                             "value": 127
#                         },
#                         {
#                             "name": "\u6a59\u6c41",
#                             "value": 35
#                         },
#                         {
#                             "name": "\u7eff\u8336",
#                             "value": 130
#                         },
#                         {
#                             "name": "\u5976\u8336",
