# %%
# import sys
# sys.path.append("../")
import pandas as pd
from pyecharts.faker import Faker
from pandasecharts import echart

# %%
products = Faker.choose()
dfs = []
for year in (2012, 2013, 2014, 2015):
    dfs.append(
        pd.DataFrame(
            zip(products, Faker.provinces, Faker.values(), Faker.values(), [year]*len(products)),
            columns=["商品", "省份", "商家A", "商家B", "年份"]
        )
    )
df = pd.concat(dfs, axis=0)

# %% [markdown]
# 2012年商家A的不同省份的总销量

# %%
df.query("年份==2012").echart.map("省份", "商家A", maptype="china", visualmap=True, agg_func="sum").render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="11f35df2cd004dea866c807b19d96748" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_11f35df2cd004dea866c807b19d96748 = echarts.init(
#                     document.getElementById('11f35df2cd004dea866c807b19d96748'), 'white', {renderer: 'canvas'});
#                 var option_11f35df2cd004dea866c807b19d96748 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %% [markdown]
# 多个年份商家A的不同省份总销量

# %%
df.echart.map("省份", "商家A", maptype="china", visualmap=True, agg_func="sum", by="年份").render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="e6245d4b40684a199eaf9cea32b323ce" style="width:900px; height:500px;"></div>
#         <div id="996907dc40a24f1a824cfa895e3e7089" style="width:900px; height:500px;"></div>
#         <div id="437a032a65c04158bd0a80744d22df2d" style="width:900px; height:500px;"></div>
#         <div id="bee8fb40796549b5a18483c5114d01e0" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_e6245d4b40684a199eaf9cea32b323ce = echarts.init(
#                     document.getElementById('e6245d4b40684a199eaf9cea32b323ce'), 'white', {renderer: 'canvas'});
#                 var option_e6245d4b40684a199eaf9cea32b323ce = {
#     "animation": true,
#     "animationThreshold": 2000,
# ...

# %% [markdown]
# 年份作时间轴显示

# %%
df.echart.map("省份", "商家A", maptype="china", visualmap=True, agg_func="sum", timeline="年份").render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="8ffe43f6ac1a4073adb3ef8a8ae1e5b4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_8ffe43f6ac1a4073adb3ef8a8ae1e5b4 = echarts.init(
#                     document.getElementById('8ffe43f6ac1a4073adb3ef8a8ae1e5b4'), 'white', {renderer: 'canvas'});
#                 var option_8ffe43f6ac1a4073adb3ef8a8ae1e5b4 = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "map",
#                 "name": "\u5546\u5bb6A",
#                 "label": {
#                     "show": false,
#                     "position": "top",
#                     "margin": 8
#                 },
#                 "mapType": "china",
# ...
