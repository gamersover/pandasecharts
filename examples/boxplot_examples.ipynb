# %%
# import sys
# sys.path.append("../")
import pandas as pd
from pyecharts.faker import Faker
from pandasecharts import echart

# %%
products = Faker.choose()
dfs = []
for year in (2012, 2013, 2014, 2015):
    dfs.append(
        pd.DataFrame(
            zip(products, Faker.values(), Faker.values(), [year]*len(products)),
            columns=["商品", "商家A", "商家B", "年份"]
        )
    )
df = pd.concat(dfs, axis=0)

# %%
df.head()
# Out:
#    商品  商家A  商家B    年份
# 0  周一   55  143  2012
# 1  周二  141  118  2012
# 2  周三   26   79  2012
# 3  周四   89   47  2012
# 4  周五   34  120  2012

# %% [markdown]
# 2012年商家A的各商品分布

# %%
df.query("年份==2012").echart.boxplot("商家A").render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="27678b3ebb7544d1a9b3f9ccf2e555e6" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_27678b3ebb7544d1a9b3f9ccf2e555e6 = echarts.init(
#                     document.getElementById('27678b3ebb7544d1a9b3f9ccf2e555e6'), 'white', {renderer: 'canvas'});
#                 var option_27678b3ebb7544d1a9b3f9ccf2e555e6 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# 2012年所有商家分布

# %%
df.query("年份==2012").echart.boxplot(["商家A", "商家B"]).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c2efe84064cc474cba467400e8bf056c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c2efe84064cc474cba467400e8bf056c = echarts.init(
#                     document.getElementById('c2efe84064cc474cba467400e8bf056c'), 'white', {renderer: 'canvas'});
#                 var option_c2efe84064cc474cba467400e8bf056c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# 不同年份商家商品分布

# %%
df.echart.boxplot(["商家A", "商家B"], by="年份").render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="fd9f80d2fb874c798d6f30aa5e98fb42" style="width:900px; height:500px;"></div>
#         <div id="39a29a21ce7e4bba9d9581005db43d9e" style="width:900px; height:500px;"></div>
#         <div id="8efb956c251240cfaa7c17f417dd5a02" style="width:900px; height:500px;"></div>
#         <div id="f817e5de9d1843efa64ce25736bbdc00" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_fd9f80d2fb874c798d6f30aa5e98fb42 = echarts.init(
#                     document.getElementById('fd9f80d2fb874c798d6f30aa5e98fb42'), 'white', {renderer: 'canvas'});
#                 var option_fd9f80d2fb874c798d6f30aa5e98fb42 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
# ...

# %% [markdown]
# 将年份作为时间轴显示

# %%
df.echart.boxplot(["商家A", "商家B"], timeline="年份").render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="214d54d5f4d549f69c4e11d5bc48c569" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_214d54d5f4d549f69c4e11d5bc48c569 = echarts.init(
#                     document.getElementById('214d54d5f4d549f69c4e11d5bc48c569'), 'white', {renderer: 'canvas'});
#                 var option_214d54d5f4d549f69c4e11d5bc48c569 = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "boxplot",
#                 "name": "\u5546\u5bb6A",
#                 "data": [
#                     [
#                         23,
#                         28,
#                         57,
#                         143,
#                         149
#                     ]
#                 ],
#                 "label": {
# ...
