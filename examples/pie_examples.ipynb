# %%
# import sys
# sys.path.append("../")
import pandas as pd
from pyecharts.faker import Faker
from pandasecharts import echart
from pandasecharts.echart import DataFrameEcharts as DFE

# %%
products = Faker.choose()
dfs = []
for year in (2012, 2013, 2014, 2015):
    dfs.append(
        pd.DataFrame(
            zip(products, Faker.values(), Faker.values(), [year]*len(products)),
            columns=["商品", "商家A", "商家B", "年份"]
        )
    )
df = pd.concat(dfs, axis=0)

# %%
df.head()
# Out:
#    商品  商家A  商家B    年份
# 0  衬衫   38  141  2012
# 1  毛衣   57   24  2012
# 2  领带   28   26  2012
# 3  裤子   89  148  2012
# 4  风衣  136   81  2012

# %%
t_2012: "DFE" = df.query("年份 == 2012").echart
t_all: "DFE" = df.echart

# %% [markdown]
# 显示2012年商家A的商品销量分布

# %%
t_2012.pie("商品", "商家A").render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="bc1cc4de9fff418184a89e31b505b5ac" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_bc1cc4de9fff418184a89e31b505b5ac = echarts.init(
#                     document.getElementById('bc1cc4de9fff418184a89e31b505b5ac'), 'white', {renderer: 'canvas'});
#                 var option_bc1cc4de9fff418184a89e31b505b5ac = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# label设置

# %%
t_2012.pie("商品", "商家A", label_opts={"position": "outer"}).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="7d6ef7a2e7ee403fa72f2f06c411f905" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_7d6ef7a2e7ee403fa72f2f06c411f905 = echarts.init(
#                     document.getElementById('7d6ef7a2e7ee403fa72f2f06c411f905'), 'white', {renderer: 'canvas'});
#                 var option_7d6ef7a2e7ee403fa72f2f06c411f905 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# pie样式之半径设置

# %%
t_2012.pie("商品", "商家A", 
                                 label_opts={"position": "outer"},
                                 radius = ["50%", "70%"],
                                 ).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="186a5d139d4442da97157e9bd384daf3" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_186a5d139d4442da97157e9bd384daf3 = echarts.init(
#                     document.getElementById('186a5d139d4442da97157e9bd384daf3'), 'white', {renderer: 'canvas'});
#                 var option_186a5d139d4442da97157e9bd384daf3 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# pie样式之rosetype设置

# %%
t_2012.pie("商品", "商家A", 
                                 label_show=False,
                                 rosetype = "radius"
                                 ).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="9583a4d77911416789dcda1eeacecac6" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9583a4d77911416789dcda1eeacecac6 = echarts.init(
#                     document.getElementById('9583a4d77911416789dcda1eeacecac6'), 'white', {renderer: 'canvas'});
#                 var option_9583a4d77911416789dcda1eeacecac6 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# legend设置

# %%
t_2012.pie("商品", "商家A", label_show=False, 
                                 legend_opts={"orient": "vertical", "pos_left": "80%"}
                                 ).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="700dca37ff344790a87e3808e81c2b85" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_700dca37ff344790a87e3808e81c2b85 = echarts.init(
#                     document.getElementById('700dca37ff344790a87e3808e81c2b85'), 'white', {renderer: 'canvas'});
#                 var option_700dca37ff344790a87e3808e81c2b85 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# 主题设置

# %%
t_2012.pie("商品", "商家A", theme="light", label_show=False).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="744f2d2232f6407eb90261d65cca560d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_744f2d2232f6407eb90261d65cca560d = echarts.init(
#                     document.getElementById('744f2d2232f6407eb90261d65cca560d'), 'light', {renderer: 'canvas'});
#                 var option_744f2d2232f6407eb90261d65cca560d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "pie",
#             "name": "\u5546\u5bb6A",
#             "clockwise": true,
# ...

# %% [markdown]
# 所有年份总销量分布

# %%
t_all.pie("商品", "商家A", label_show=False, agg_func="sum").render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a195fb644d12401384cc0a5a6dba6e0a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a195fb644d12401384cc0a5a6dba6e0a = echarts.init(
#                     document.getElementById('a195fb644d12401384cc0a5a6dba6e0a'), 'white', {renderer: 'canvas'});
#                 var option_a195fb644d12401384cc0a5a6dba6e0a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# 按照年份显示多张图表

# %%
t_all.pie("商品", "商家A", label_show=False, by="年份").render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a3aae4db7023464f8bc18dcd610b6cba" style="width:900px; height:500px;"></div>
#         <div id="9480b34929bf44bfacbf0fc4f7639de7" style="width:900px; height:500px;"></div>
#         <div id="ac4ba9d588844474a18f41928c4ac6d3" style="width:900px; height:500px;"></div>
#         <div id="70cd2f0fa52f4f7cad972ca444dedf41" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a3aae4db7023464f8bc18dcd610b6cba = echarts.init(
#                     document.getElementById('a3aae4db7023464f8bc18dcd610b6cba'), 'white', {renderer: 'canvas'});
#                 var option_a3aae4db7023464f8bc18dcd610b6cba = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
# ...

# %% [markdown]
# 以时间轴显示多个年份

# %%
t_all.pie("商品", "商家A", 
               timeline="年份",
               label_show=False,
              ).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="83166b68531349e0a183223bbf2935de" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_83166b68531349e0a183223bbf2935de = echarts.init(
#                     document.getElementById('83166b68531349e0a183223bbf2935de'), 'white', {renderer: 'canvas'});
#                 var option_83166b68531349e0a183223bbf2935de = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "pie",
#                 "name": "\u5546\u5bb6A",
#                 "clockwise": true,
#                 "data": [
#                     {
#                         "name": "\u886c\u886b",
#                         "value": 61
#                     },
#                     {
#                         "name": "\u6bdb\u8863",
# ...
