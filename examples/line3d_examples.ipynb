# %%
# import sys
# sys.path.append("../")
import pandas as pd
from pyecharts.faker import Faker
from pandasecharts import echart
from pandasecharts.echart import DataFrameEcharts as DFE

# %%
products = Faker.choose()
dfs = []
for year in (2012, 2013, 2014, 2015):
    dfs.append(
        pd.DataFrame(
            zip(products, Faker.values(), Faker.values(), [year]*len(products)),
            columns=["商品", "商家A", "商家B", "年份"]
        )
    )
df = pd.concat(dfs, axis=0)

# %%
df.head()
# Out:
#    商品  商家A  商家B    年份
# 0  可乐  117   78  2012
# 1  雪碧  111   41  2012
# 2  橙汁   87  108  2012
# 3  绿茶   83   93  2012
# 4  奶茶   79   34  2012

# %%
t_all: "DFE" = df.echart

# %%
t_all.line3d("年份", "商品", "商家B", xtype="category", ytype="category", ztype="value", visualmap=True).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-gl':'https://assets.pyecharts.org/assets/echarts-gl.min'
#         }
#     });
# </script>
#
#         <div id="61cd697cbfbb4c7492e7567dba1a0a7d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-gl'], function(echarts) {
#                 var chart_61cd697cbfbb4c7492e7567dba1a0a7d = echarts.init(
#                     document.getElementById('61cd697cbfbb4c7492e7567dba1a0a7d'), 'white', {renderer: 'canvas'});
#                 var option_61cd697cbfbb4c7492e7567dba1a0a7d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line3D",
#             "data": [
#                 [
#                     2012,
#                     "\u53ef\u4e50",
#                     78
#                 ],
#                 [
#                     2012,
#                     "\u96ea\u78a7",
#                     41
#                 ],
#                 [
#                     2012,
#                     "\u6a59\u6c41",
#                     108
#                 ],
#                 [
#                     2012,
#                     "\u7eff\u8336",
#                     93
#                 ],
#                 [
#                     2012,
#                     "\u5976\u8336",
#                     34
#                 ],
#                 [
#                     2012,
#                     "\u767e\u5a01",
#                     73
#                 ],
#                 [
#                     2012,
#                     "\u9752\u5c9b",
#                     123
#                 ],
#                 [
#                     2013,
#                     "\u53ef\u4e50",
#                     58
#                 ],
#                 [
#                     2013,
#                     "\u96ea\u78a7",
#                     139
#                 ],
#                 [
#                     2013,
#                     "\u6a59\u6c41",
#                     52
#                 ],
#                 [
#                     2013,
#                     "\u7eff\u8336",
#                     130
#                 ],
#                 [
#                     2013,
#                     "\u5976\u8336",
#                     95
#                 ],
#                 [
#                     2013,
#                     "\u767e\u5a01",
#                     36
#                 ],
#                 [
#                     2013,
#                     "\u9752\u5c9b",
#                     25
#                 ],
#                 [
#                     2014,
#                     "\u53ef\u4e50",
#                     49
#                 ],
#                 [
#                     2014,
#                     "\u96ea\u78a7",
#                     48
#                 ],
#                 [
#                     2014,
#                     "\u6a59\u6c41",
#                     116
#                 ],
#                 [
#                     2014,
#                     "\u7eff\u8336",
#                     101
#                 ],
#                 [
#                     2014,
#                     "\u5976\u8336",
#                     136
#                 ],
#                 [
#                     2014,
#                     "\u767e\u5a01",
#                     123
#                 ],
#                 [
#                     2014,
#                     "\u9752\u5c9b",
#                     44
#                 ],
#                 [
#                     2015,
#                     "\u53ef\u4e50",
#                     148
#                 ],
#                 [
#                     2015,
#                     "\u96ea\u78a7",
#                     68
#                 ],
#                 [
#                     2015,
#                     "\u6a59\u6c41",
#                     111
#                 ],
#                 [
#                     2015,
#                     "\u7eff\u8336",
#                     71
#                 ],
#                 [
#                     2015,
#                     "\u5976\u8336",
#                     114
#                 ],
#                 [
#                     2015,
#                     "\u767e\u5a01",
#                     128
#                 ],
#                 [
#                     2015,
#                     "\u9752\u5c9b",
#                     87
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 25,
#         "max": 148,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     },
#     "xAxis3D": {
#         "name": "\u5e74\u4efd",
#         "nameGap": 20,
#         "type": "category",
#         "axisLabel": {
#             "margin": 8
#         }
#     },
#     "yAxis3D": {
#         "name": "\u5546\u54c1",
#         "nameGap": 20,
#         "type": "category",
#         "axisLabel": {
#             "margin": 8
#         }
#     },
#     "zAxis3D": {
#         "name": "\u5546\u5bb6B",
#         "nameGap": 20,
#         "type": "value",
#         "axisLabel": {
#             "margin": 8
#         }
#     },
#     "grid3D": {
#         "boxWidth": 200,
#         "boxHeight": 100,
#         "boxDepth": 80,
#         "viewControl": {
#             "autoRotate": false,
#             "autoRotateSpeed": 10,
#             "rotateSensitivity": 1
#         }
#     },
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_61cd697cbfbb4c7492e7567dba1a0a7d.setOption(option_61cd697cbfbb4c7492e7567dba1a0a7d);
#         });
#     </script>
